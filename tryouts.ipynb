# %%
#importing the packages
import pandas as pd
import sys
from scipy import sparse 
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity

#importing warnings to turn off future warnings
import warnings
warnings.simplefilter(action='ignore')

# %%
#reading in the data
explicit_ratings = pd.read_csv('explicit_ratings.csv')
explicit_ratings.head()
# Out:
#    Unnamed: 0  user_id  book_id  rating  goodreads_book_id  tag_id  count  \
# 0           0     2886        1       5            2767052   11305  10836
# 1           1        4        2       5                  3   11305  47478
# 2           2      451        3       5              41865   11305  14288
# 3           3       15        4       3               2657   14487   4735
# 4           4        4        5       4               4671   14487   2394
#
#            tag_name.x     genre.x          tag_name.y  ... ratings_count  \
# 0             fantasy     fantasy             fantasy  ...       4780653
# 1             fantasy     fantasy             fantasy  ...       4602479
# 2             fantasy     fantasy             fantasy  ...       3866839
# 3  historical-fiction  historical  historical-fiction  ...       3198671
# 4  historical-fiction  historical  historical-fiction  ...       2683664
#
#    work_ratings_count  work_text_reviews_count  ratings_1 ratings_2  \
# 0             4942365                   155254      66715    127936
# 1             4800065                    75867      75504    101676
# 2             3916824                    95009     456191    436802
# 3             3340896                    72586      60427    117415
# 4             2773745                    51992      86236    197621
#
#    ratings_3 ratings_4  ratings_5  \
# 0     560092   1481305    2706317
# 1     455024   1156318    3011543
# 2     793319    875073    1355439
# 3     446835   1001952    1714267
# 4     606158    936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 32 columns]

# %%
for col in explicit_ratings.columns: 
    print(col)
# Out:
# Unnamed: 0
# user_id
# book_id
# rating
# goodreads_book_id
# tag_id
# count
# tag_name.x
# genre.x
# tag_name.y
# genre.y
# best_book_id
# work_id
# books_count
# isbn
# isbn13
# authors
# original_publication_year
# original_title
# title
# language_code
# average_rating
# ratings_count
# work_ratings_count
# work_text_reviews_count
# ratings_1
# ratings_2
# ratings_3
# ratings_4
# ratings_5
# image_url
# small_image_url

# %%
#Dropping unneeded columns
explicit_ratings.drop(['Unnamed: 0','goodreads_book_id', 'tag_id', 'count', 'tag_name.x','tag_name.y','genre.y', 'best_book_id', 'work_id', 'books_count','isbn','isbn13', 'original_publication_year', 'original_title', 'ratings_count','work_ratings_count','work_text_reviews_count','ratings_1','ratings_2','ratings_3','ratings_4','ratings_5','small_image_url','image_url','language_code'], 1,  inplace=True)

# %%
explicit_ratings.head()
# Out:
#    user_id  book_id  rating     genre.x                      authors  \
# 0     2886        1       5     fantasy              Suzanne Collins
# 1        4        2       5     fantasy  J.K. Rowling, Mary GrandPré
# 2      451        3       5     fantasy              Stephenie Meyer
# 3       15        4       3  historical                   Harper Lee
# 4        4        5       4  historical          F. Scott Fitzgerald
#
#                                                title  average_rating
# 0            The Hunger Games (The Hunger Games, #1)            4.34
# 1  Harry Potter and the Sorcerer's Stone (Harry P...            4.44
# 2                            Twilight (Twilight, #1)            3.57
# 3                              To Kill a Mockingbird            4.25
# 4                                   The Great Gatsby            3.89

# %%
# # #data for pivot table
# #Creating a sample of users -who have more than 200 ratings
# user_counts = explicit_ratings['user_id'].value_counts()
# sample_ratings = explicit_ratings[explicit_ratings['user_id'].isin(user_counts[user_counts >= 3].index)]

# %%
#check the size and shape
sample_ratings.shape
# Out:
# (6027, 7)

# %% [markdown]
# ## Pivot table

# %%
#seeing if my sample size is small enough to create a pivot table
pivot = explicit_ratings.pivot_table(index='title', columns='user_id', values='rating')

# %%
pivot.shape
# Out:
# (9940, 4149)

# %% [markdown]
# ## Sparse matrix

# %%
#getting the size of the pivot file
sys.getsizeof(pivot)
# Out:
# 330826830

# %%
#preprocessing step of converting nans to zeros.
pivot_sparse = sparse.csr_matrix(pivot.fillna(0))

# %%
#getting the updated file size
sys.getsizeof(pivot_sparse)
# Out:
# 64

# %% [markdown]
# ## Recommender

# %%
#setting up the recommender 
recommender = cosine_similarity(pivot_sparse)

# %%
#verifying the shape of the engine to make sure the numbers are the same
recommender.shape
# Out:
# (9940, 9940)

# %%
#creating a dataframe to bring the title names back into view
recommender_df = pd.DataFrame(recommender, columns=pivot.index, index=pivot.index)
recommender_df.head(10)
# Out:
# title                                                Angels (Walsh Family, #3)  \
# title
#  Angels (Walsh Family, #3)                                                 1.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                           0.0
# #GIRLBOSS                                                                  0.0
# 'Salem's Lot                                                               0.0
# 'Tis (Frank McCourt, #2)                                                   0.0
# 1,000 Places to See Before You Die                                         0.0
# 1/4 جرام                                                                   0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                         0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                 0.0
# 100 Love Sonnets                                                           0.0
#
# title                                               "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية  \
# title
#  Angels (Walsh Family, #3)                                                                       0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                                 1.0
# #GIRLBOSS                                                                                        0.0
# 'Salem's Lot                                                                                     0.0
# 'Tis (Frank McCourt, #2)                                                                         0.0
# 1,000 Places to See Before You Die                                                               0.0
# 1/4 جرام                                                                                         0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                               0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                                       0.0
# 100 Love Sonnets                                                                                 0.0
#
# title                                               #GIRLBOSS  'Salem's Lot  \
# title
#  Angels (Walsh Family, #3)                                0.0           0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية          0.0           0.0
# #GIRLBOSS                                                 1.0           0.0
# 'Salem's Lot                                              0.0           1.0
# 'Tis (Frank McCourt, #2)                                  0.0           0.0
# 1,000 Places to See Before You Die                        0.0           0.0
# 1/4 جرام                                                  0.0           0.0
# 10% Happier: How I Tamed the Voice in My Head, ...        0.0           0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                0.0           0.0
# 100 Love Sonnets                                          0.0           0.0
#
# title                                               'Tis (Frank McCourt, #2)  \
# title
#  Angels (Walsh Family, #3)                                               0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                         0.0
# #GIRLBOSS                                                                0.0
# 'Salem's Lot                                                             0.0
# 'Tis (Frank McCourt, #2)                                                 1.0
# 1,000 Places to See Before You Die                                       0.0
# 1/4 جرام                                                                 0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                       0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                               0.0
# 100 Love Sonnets                                                         0.0
#
# title                                               1,000 Places to See Before You Die  \
# title
#  Angels (Walsh Family, #3)                                                         0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                   0.0
# #GIRLBOSS                                                                          0.0
# 'Salem's Lot                                                                       0.0
# 'Tis (Frank McCourt, #2)                                                           0.0
# 1,000 Places to See Before You Die                                                 1.0
# 1/4 جرام                                                                           0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                 0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                         0.0
# 100 Love Sonnets                                                                   0.0
#
# title                                               1/4 جرام  \
# title
#  Angels (Walsh Family, #3)                               0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية         0.0
# #GIRLBOSS                                                0.0
# 'Salem's Lot                                             0.0
# 'Tis (Frank McCourt, #2)                                 0.0
# 1,000 Places to See Before You Die                       0.0
# 1/4 جرام                                                 1.0
# 10% Happier: How I Tamed the Voice in My Head, ...       0.0
# 100 Bullets, Vol. 1: First Shot, Last Call               0.0
# 100 Love Sonnets                                         0.0
#
# title                                               10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works  \
# title
#  Angels (Walsh Family, #3)                                                                        0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                                  0.0
# #GIRLBOSS                                                                                         0.0
# 'Salem's Lot                                                                                      0.0
# 'Tis (Frank McCourt, #2)                                                                          0.0
# 1,000 Places to See Before You Die                                                                0.0
# 1/4 جرام                                                                                          0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                                1.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                                        0.0
# 100 Love Sonnets                                                                                  0.0
#
# title                                               100 Bullets, Vol. 1: First Shot, Last Call  \
# title
#  Angels (Walsh Family, #3)                                                                 0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                           0.0
# #GIRLBOSS                                                                                  0.0
# 'Salem's Lot                                                                               0.0
# 'Tis (Frank McCourt, #2)                                                                   0.0
# 1,000 Places to See Before You Die                                                         0.0
# 1/4 جرام                                                                                   0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                         0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                                 1.0
# 100 Love Sonnets                                                                           0.0
#
# title                                               100 Love Sonnets  ...  \
# title                                                                 ...
#  Angels (Walsh Family, #3)                                       0.0  ...
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                 0.0  ...
# #GIRLBOSS                                                        0.0  ...
# 'Salem's Lot                                                     0.0  ...
# 'Tis (Frank McCourt, #2)                                         0.0  ...
# 1,000 Places to See Before You Die                               0.0  ...
# 1/4 جرام                                                         0.0  ...
# 10% Happier: How I Tamed the Voice in My Head, ...               0.0  ...
# 100 Bullets, Vol. 1: First Shot, Last Call                       0.0  ...
# 100 Love Sonnets                                                 1.0  ...
#
# title                                               ماهی سیاه کوچولو  \
# title
#  Angels (Walsh Family, #3)                                       0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                 0.0
# #GIRLBOSS                                                        0.0
# 'Salem's Lot                                                     0.0
# 'Tis (Frank McCourt, #2)                                         0.0
# 1,000 Places to See Before You Die                               0.0
# 1/4 جرام                                                         0.0
# 10% Happier: How I Tamed the Voice in My Head, ...               0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                       0.0
# 100 Love Sonnets                                                 0.0
#
# title                                               مخطوطة بن إسحاق: مدينة الموتى  \
# title
#  Angels (Walsh Family, #3)                                                    0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                              0.0
# #GIRLBOSS                                                                     0.0
# 'Salem's Lot                                                                  0.0
# 'Tis (Frank McCourt, #2)                                                      0.0
# 1,000 Places to See Before You Die                                            0.0
# 1/4 جرام                                                                      0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                            0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                    0.0
# 100 Love Sonnets                                                              0.0
#
# title                                               نادي السيارات  هشت کتاب  \
# title
#  Angels (Walsh Family, #3)                                    0.0       0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية              0.0       0.0
# #GIRLBOSS                                                     0.0       0.0
# 'Salem's Lot                                                  0.0       0.0
# 'Tis (Frank McCourt, #2)                                      0.0       0.0
# 1,000 Places to See Before You Die                            0.0       0.0
# 1/4 جرام                                                      0.0       0.0
# 10% Happier: How I Tamed the Voice in My Head, ...            0.0       0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                    0.0       0.0
# 100 Love Sonnets                                              0.0       0.0
#
# title                                               هيبتا  واحة الغروب  \
# title
#  Angels (Walsh Family, #3)                            0.0          0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية      0.0          0.0
# #GIRLBOSS                                             0.0          0.0
# 'Salem's Lot                                          0.0          0.0
# 'Tis (Frank McCourt, #2)                              0.0          0.0
# 1,000 Places to See Before You Die                    0.0          0.0
# 1/4 جرام                                              0.0          0.0
# 10% Happier: How I Tamed the Voice in My Head, ...    0.0          0.0
# 100 Bullets, Vol. 1: First Shot, Last Call            0.0          0.0
# 100 Love Sonnets                                      0.0          0.0
#
# title                                               يوتوبيا  ڤيرتيجو  \
# title
#  Angels (Walsh Family, #3)                              0.0      0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية        0.0      0.0
# #GIRLBOSS                                               0.0      0.0
# 'Salem's Lot                                            0.0      0.0
# 'Tis (Frank McCourt, #2)                                0.0      0.0
# 1,000 Places to See Before You Die                      0.0      0.0
# 1/4 جرام                                                0.0      0.0
# 10% Happier: How I Tamed the Voice in My Head, ...      0.0      0.0
# 100 Bullets, Vol. 1: First Shot, Last Call              0.0      0.0
# 100 Love Sonnets                                        0.0      0.0
#
# title                                               キスよりも早く1 [Kisu Yorimo Hayaku 1] (Faster than a Kiss #1)  \
# title
#  Angels (Walsh Family, #3)                                                                        0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                                  0.0
# #GIRLBOSS                                                                                         0.0
# 'Salem's Lot                                                                                      0.0
# 'Tis (Frank McCourt, #2)                                                                          0.0
# 1,000 Places to See Before You Die                                                                0.0
# 1/4 جرام                                                                                          0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                                0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                                        0.0
# 100 Love Sonnets                                                                                  0.0
#
# title                                               美少女戦士セーラームーン新装版 1 [Bishōjo Senshi Sailor Moon Shinsōban 1]
# title
#  Angels (Walsh Family, #3)                                                                        0.0
# "حكايات فرغلي المستكاوي "حكايتى مع كفر السحلاوية                                                  0.0
# #GIRLBOSS                                                                                         0.0
# 'Salem's Lot                                                                                      0.0
# 'Tis (Frank McCourt, #2)                                                                          0.0
# 1,000 Places to See Before You Die                                                                0.0
# 1/4 جرام                                                                                          0.0
# 10% Happier: How I Tamed the Voice in My Head, ...                                                0.0
# 100 Bullets, Vol. 1: First Shot, Last Call                                                        0.0
# 100 Love Sonnets                                                                                  0.0
#
# [10 rows x 9940 columns]

# %% [markdown]
# ## Evaluation of the Recommender Engine

# %%
#setting the columns so we can see the full titles
pd.set_option('display.max_colwidth', -1)

# %%
#Code to search for titles 
q = 'Interview with the Vampire'
explicit_ratings[explicit_ratings['title'].str.contains(q)]['title'].head()
# Out:
# 203     Interview with the Vampire (The Vampire Chronicles, #1)
# 9021    Vampire Chronicles: Interview with the Vampire, The Vampire Lestat, The Queen of the Damned (Anne Rice)
# Name: title, dtype: object

# %%
#Looking up recommendations for those who liked HP:
recommender_df["Harry Potter and the Sorcerer's Stone (Harry Potter, #1)"].sort_values(ascending=False)[1:11]
# Out:
# title
# The Sun Also Rises                                             1.0
# Life of Pi                                                     1.0
# Charlie and the Chocolate Factory (Charlie Bucket, #1)         1.0
# Alexander and the Terrible, Horrible, No Good, Very Bad Day    1.0
# Alas, Babylon                                                  1.0
# The Catcher in the Rye                                         1.0
# The Ultimate Hitchhiker's Guide to the Galaxy                  1.0
# The Count of Monte Cristo                                      1.0
# The Giver (The Giver, #1)                                      1.0
# A Confederacy of Dunces                                        1.0
# Name: Harry Potter and the Sorcerer's Stone (Harry Potter, #1), dtype: float64

# %%
#Looking up recommendations for those who liked Interview with the Vampire:
recommender_df['Interview with the Vampire (The Vampire Chronicles, #1)'].sort_values(ascending=False)[1:11]
# Out:
# title
# Thinner                                                       1.0
# The Door to December                                          1.0
# From a Buick 8                                                1.0
# Pandora / Vittorio the Vampire (New Tales of the Vampires)    1.0
# Dirk Gently's Holistic Detective Agency (Dirk Gently #1)      1.0
# Pandora (New Tales of the Vampires, #1)                       1.0
# Clear and Present Danger (Jack Ryan Universe, #6)             1.0
# The Velveteen Rabbit                                          1.0
# The Sum of All Fears (Jack Ryan Universe, #7)                 1.0
# The Lost World (Professor Challenger, #1)                     1.0
# Name: Interview with the Vampire (The Vampire Chronicles, #1), dtype: float64
